# %%
from main import get_campus

# %%
df, text = await get_campus()
# Out:
# 距报名结束还有<span class="bold">1</span>天，已有211人报名，剩余89个报名名额
# 本次活动报名名额已满
# 本次活动报名名额已满
# 距报名结束还有<span class="bold">1</span>天，还有30个候补机会
# 本次活动报名名额已满

# %%
df
# Out:
#       aid                                aname  \
# 4   33165                 崇实新生导学 | 档案世界中的经济社会史
# 18  33092                形势与政策 | 中华文明的生命观与制度底色
# 3   33166  统计学院形势与政策专题讲座：《学思想强本领 努力成长为新时代合格党员》
# 12  33129                    中国式现代化：全球语境下的文明视角
# 11  33130                    中国式现代化：全球语境下的文明视角
#
#                                              abstract            begintime  \
# 4   习近平总书记在中国人民大学考察调研时强调，加快构建中国特色哲学社会科学，归根结底是建构中国自...  2023-11-22 14:00:00
# 18  为深入学习贯彻习近平总书记对宣传思想文化工作的重要指示和全国宣传思想文化工作会议精神，深刻把...  2023-11-22 14:00:00
# 3   统计学院邀请劳动人事片区专职组织员李明奎做题为《学思想强本领 努力成长为新时代合格党员》形势...  2023-11-22 14:30:00
# 12  “中国式现代化：全球语境下的文明视角”主题讲座由中国人民大学中国式现代化与文明新形态研究院、...  2023-11-26 08:45:00
# 11  “中国式现代化：全球语境下的文明视角”主题讲座，由中国人民大学中国式现代化与文明新形态研究院...  2023-11-26 14:00:00
#
#                 endtime    location partakemodename  \
# 4   2023-11-22 15:30:00      教三3201              签到
# 18  2023-11-22 15:30:00  明德主楼728会议室              签到
# 3   2023-11-22 16:00:00  公共教学一楼1402              签到
# ...

# %%
print(text)
# Out:
# 崇实新生导学 | 档案世界中的经济社会史
#     开始时间：2023-11-22 14:00:00
#     结束时间：2023-11-22 15:30:00
#     地点：教三3201
#     点名方式：签到
#     状态：我要报名
#     剩余名额：89
#     简介：习近平总书记在中国人民大学考察调研时强调，加快构建中国特色哲学社会科学，归根结底是建构中国自主的知识体系。基于《国家“十四五”时期哲学社会科学发展规划》，为深入贯彻落实党中央提出的加快构建中国特色哲学社会科学的战略任务，崇实书院开展主题为《档案世界中的经济社会史》的形势与政策讲座，邀请中国人民大学经济学院讲师、中国人民大学首届ESH（经济社会历史）实验班学术主任杨成主讲。
#     url: https://v.ruc.edu.cn/campus#/activity/partakedetail/33165/show
#
#
# 形势与政策 | 中华文明的生命观与制度底色
#     开始时间：2023-11-22 14:00:00
#     结束时间：2023-11-22 15:30:00
#     地点：明德主楼728会议室
#     点名方式：签到
#     状态：候补报名
#     剩余名额：30
#     简介：为深入学习贯彻习近平总书记对宣传思想文化工作的重要指示和全国宣传思想文化工作会议精神，深刻把握习近平文化思想的重大意义、丰富内涵和实践要求，在新的历史起点上继续推动文化繁荣、建设文化强国，经济学院开展《文化强国和中国式现代化》系列“形势与政策”讲座。本讲将围绕“中华文明的生命观与制度底色”，学习贯彻习近平文化思想，引领学生探索中国优秀传统文化与中国特色社会主义制度的内在逻辑。
#     url: https://v.ruc.edu.cn/campus#/activity/partakedetail/33092/show
#
#
# 统计学院形势与政策专题讲座：《学思想强本领 努力成长为新时代合格党员》
#     开始时间：2023-11-22 14:30:00
#     结束时间：2023-11-22 16:00:00
#     地点：公共教学一楼1402
#     点名方式：签到
#     状态：名额已满
# ...
